# %%
import nmap
import os
import sys
import re

# %%
nm = nmap.PortScanner()
nm_args = '-Pn -sT -p 9102'

# %%
clientPath = '/etc/bareos/bareos-dir.d/client/'

file_list = next(os.walk(clientPath))[2]
file_list.sort()
#file_list = ["dummy-lt.conf"]

sysRX = re.compile(r'(?i)(^.*(\-(wks|lt)))', re.MULTILINE)

for file in file_list:
    #print file
    if re.match(sysRX, file):
        m = re.match(sysRX, file)
        #print m.group(0)
        nm.scan(hosts=m.group(0), arguments=nm_args)
        print nm.all_hosts()
        for host in nm.all_hosts():
            print('----------------------------------------------------')
            print('Host : %s (%s)' % (host, nm[host].hostname()))
            # print('State : %s' % nm[host].state())
            for proto in nm[host].all_protocols():
                # print('----------')
                print('Protocol : %s' % proto)
                lport = nm[host][proto].keys()
                lport.sort()
                for port in lport:
                    print port
                    print ('port : %s\tstate : %s' % (port, nm[host][proto][port]['state']))
# Out:
# ['10.145.0.174']
# ----------------------------------------------------
# Host : 10.145.0.174 (accounting-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.3.66']
# ----------------------------------------------------
# Host : 10.144.3.66 (adalbero-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.204']
# ----------------------------------------------------
# Host : 10.145.0.204 (agilbertson-wks)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.144.1.59']
# ----------------------------------------------------
# Host : 10.144.1.59 (aheintz-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.0.235']
# ----------------------------------------------------
# Host : 10.144.0.235 (ahillman-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.163']
# ----------------------------------------------------
# Host : 10.145.0.163 (akibe-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.154']
# ----------------------------------------------------
# Host : 10.145.0.154 (aparissi-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.1.46']
# ----------------------------------------------------
# Host : 10.144.1.46 (astephens-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.160']
# ----------------------------------------------------
# Host : 10.145.0.160 (awakefield-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.2.155']
# ----------------------------------------------------
# Host : 10.144.2.155 (aworden-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.0.197']
# ----------------------------------------------------
# Host : 10.144.0.197 (bclark-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.178']
# ----------------------------------------------------
# Host : 10.145.0.178 (bflorence-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.210']
# ----------------------------------------------------
# Host : 10.145.0.210 (bhenry2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.181']
# ----------------------------------------------------
# Host : 10.145.0.181 (btrianta-wks)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.152']
# ----------------------------------------------------
# Host : 10.145.0.152 (cbadon-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.167']
# ----------------------------------------------------
# Host : 10.145.0.167 (ccondron-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.225']
# ----------------------------------------------------
# Host : 10.145.0.225 (ccramer-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.168']
# ----------------------------------------------------
# Host : 10.145.0.168 (cingram-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.95']
# ----------------------------------------------------
# Host : 10.145.4.95 (cmiskovic-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.172']
# ----------------------------------------------------
# Host : 10.145.0.172 (creative1-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.176']
# ----------------------------------------------------
# Host : 10.145.0.176 (csamsel-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.186']
# ----------------------------------------------------
# Host : 10.145.0.186 (ctkaczuk-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.97']
# ----------------------------------------------------
# Host : 10.145.4.97 (ctruitt-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.157']
# ----------------------------------------------------
# Host : 10.145.0.157 (cwiltshire-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.248']
# ----------------------------------------------------
# Host : 10.145.0.248 (dmarshall-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.253']
# ----------------------------------------------------
# Host : 10.145.0.253 (droberts-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# []
# ['10.145.0.157']
# ----------------------------------------------------
# Host : 10.145.0.157 (e5430loaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.157']
# ----------------------------------------------------
# Host : 10.145.0.157 (e5430testing-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.169']
# ----------------------------------------------------
# Host : 10.145.0.169 (e6530loaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.4.95']
# ----------------------------------------------------
# Host : 10.145.4.95 (esimensen-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.99']
# ----------------------------------------------------
# Host : 10.145.4.99 (gbirch-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.144.2.131']
# ----------------------------------------------------
# Host : 10.144.2.131 (gsteir-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.0.95']
# ----------------------------------------------------
# Host : 10.144.0.95 (jborochaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.159']
# ----------------------------------------------------
# Host : 10.145.0.159 (jcross-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.191']
# ----------------------------------------------------
# Host : 10.145.4.191 (jdurff-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.0.106']
# ----------------------------------------------------
# Host : 10.144.0.106 (jenmazzoni-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.190']
# ----------------------------------------------------
# Host : 10.145.0.190 (jmazzarella-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.170']
# ----------------------------------------------------
# Host : 10.145.0.170 (jobrien-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.1.19']
# ----------------------------------------------------
# Host : 10.144.1.19 (jpeck-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.130']
# ----------------------------------------------------
# Host : 10.145.0.130 (jreynolds-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.0.228']
# ----------------------------------------------------
# Host : 10.144.0.228 (jsparling-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.98']
# ----------------------------------------------------
# Host : 10.145.4.98 (kamerman-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.2.151']
# ----------------------------------------------------
# Host : 10.144.2.151 (kblaine-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.49']
# ----------------------------------------------------
# Host : 10.145.4.49 (kbraddish-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.245']
# ----------------------------------------------------
# Host : 10.145.0.245 (khammar-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.178']
# ----------------------------------------------------
# Host : 10.145.0.178 (kkamparath-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.197']
# ----------------------------------------------------
# Host : 10.145.0.197 (lbartow-wks)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.200']
# ----------------------------------------------------
# Host : 10.145.4.200 (lindsay-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.2.242']
# ----------------------------------------------------
# Host : 10.144.2.242 (lreed-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.156']
# ----------------------------------------------------
# Host : 10.145.0.156 (lreed2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.189']
# ----------------------------------------------------
# Host : 10.145.0.189 (lsaripalli-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.143']
# ----------------------------------------------------
# Host : 10.145.0.143 (lwapnitsky-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.144.0.214']
# ----------------------------------------------------
# Host : 10.144.0.214 (manthony-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.100']
# ----------------------------------------------------
# Host : 10.145.4.100 (marnold-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.0.206']
# ----------------------------------------------------
# Host : 10.144.0.206 (mdavis-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.191']
# ----------------------------------------------------
# Host : 10.145.0.191 (mgoldstein-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.183']
# ----------------------------------------------------
# Host : 10.145.0.183 (mhorsch-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.215']
# ----------------------------------------------------
# Host : 10.145.0.215 (mmainardi-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.107']
# ----------------------------------------------------
# Host : 10.145.4.107 (mrempfer-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.4.93']
# ----------------------------------------------------
# Host : 10.145.4.93 (msmith-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.199']
# ----------------------------------------------------
# Host : 10.145.0.199 (mstrassman-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.177']
# ----------------------------------------------------
# Host : 10.145.0.177 (nicole-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.165']
# ----------------------------------------------------
# Host : 10.145.0.165 (owen-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.175']
# ----------------------------------------------------
# Host : 10.145.0.175 (powers-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# []
# []
# ['10.145.4.105']
# ----------------------------------------------------
# Host : 10.145.4.105 (rbaretto-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# []
# ['10.145.0.188']
# ----------------------------------------------------
# Host : 10.145.0.188 (rgarrett-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.70']
# ----------------------------------------------------
# Host : 10.145.4.70 (rino-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.161']
# ----------------------------------------------------
# Host : 10.145.0.161 (shagarty-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.193']
# ----------------------------------------------------
# Host : 10.145.0.193 (snuzzo-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.225']
# ----------------------------------------------------
# Host : 10.145.4.225 (sreilly-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.0.102']
# ----------------------------------------------------
# Host : 10.144.0.102 (svats-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.108']
# ----------------------------------------------------
# Host : 10.145.4.108 (sweiland-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.181']
# ----------------------------------------------------
# Host : 10.145.0.181 (swray-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.175']
# ----------------------------------------------------
# Host : 10.145.0.175 (tdunn2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.235']
# ----------------------------------------------------
# Host : 10.145.0.235 (thall-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.102']
# ----------------------------------------------------
# Host : 10.145.4.102 (tharness-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.202']
# ----------------------------------------------------
# Host : 10.145.0.202 (thoward-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.241']
# ----------------------------------------------------
# Host : 10.145.0.241 (tlowell-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.146']
# ----------------------------------------------------
# Host : 10.145.0.146 (xpsloaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
