# %%
import nmap
import os
import sys
import re

# %%
nm = nmap.PortScanner()
nm_args = '-Pn -sT -p 9102'

# %%
clientPath = '/etc/bareos/bareos-dir.d/client/'

file_list = next(os.walk(clientPath))[2]
file_list.sort()
#file_list = ["dummy-lt.conf"]

sysRX = re.compile(r'(?i)(^.*(\-(wks|lt)))', re.MULTILINE)

for file in file_list:
    #print file
    if re.match(sysRX, file):
        m = re.match(sysRX, file)
        #print m.group(0)
        nm.scan(hosts=m.group(0), arguments=nm_args)
        print nm.all_hosts()
        for host in nm.all_hosts():
            print('----------------------------------------------------')
            print('Host : %s (%s)' % (host, nm[host].hostname()))
            # print('State : %s' % nm[host].state())
            for proto in nm[host].all_protocols():
                # print('----------')
                print('Protocol : %s' % proto)
                lport = nm[host][proto].keys()
                lport.sort()
                for port in lport:
                    print port
                    print ('port : %s\tstate : %s' % (port, nm[host][proto][port]['state']))
# Out:
# ['10.145.0.174']
# ----------------------------------------------------
# Host : 10.145.0.174 (accounting-wks)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.1.253']
# ----------------------------------------------------
# Host : 10.144.1.253 (adalbero-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.204']
# ----------------------------------------------------
# Host : 10.145.0.204 (agilbertson-wks)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.128']
# ----------------------------------------------------
# Host : 10.145.0.128 (aheintz-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.162']
# ----------------------------------------------------
# Host : 10.145.4.162 (ahillman-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.117']
# ----------------------------------------------------
# Host : 10.145.0.117 (akibe-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.129']
# ----------------------------------------------------
# Host : 10.145.0.129 (aparissi-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.164']
# ----------------------------------------------------
# Host : 10.145.4.164 (astephens-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.175']
# ----------------------------------------------------
# Host : 10.145.0.175 (awakefield-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.2.155']
# ----------------------------------------------------
# Host : 10.144.2.155 (aworden-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.174']
# ----------------------------------------------------
# Host : 10.145.4.174 (bclark-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.206']
# ----------------------------------------------------
# Host : 10.145.0.206 (bflorence-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.210']
# ----------------------------------------------------
# Host : 10.145.0.210 (bhenry2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.215']
# ----------------------------------------------------
# Host : 10.145.0.215 (btrianta-wks)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.122']
# ----------------------------------------------------
# Host : 10.145.0.122 (cbadon-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.163']
# ----------------------------------------------------
# Host : 10.145.4.163 (ccondron-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.225']
# ----------------------------------------------------
# Host : 10.145.0.225 (ccramer-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.210']
# ----------------------------------------------------
# Host : 10.145.0.210 (cingram-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.4.160']
# ----------------------------------------------------
# Host : 10.145.4.160 (cmiskovic-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.221']
# ----------------------------------------------------
# Host : 10.145.0.221 (creative1-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.153']
# ----------------------------------------------------
# Host : 10.145.0.153 (csamsel-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.168']
# ----------------------------------------------------
# Host : 10.145.4.168 (ctkaczuk-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.166']
# ----------------------------------------------------
# Host : 10.145.4.166 (ctruitt-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# []
# ['10.145.0.224']
# ----------------------------------------------------
# Host : 10.145.0.224 (dmarshall-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.253']
# ----------------------------------------------------
# Host : 10.145.0.253 (droberts-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# []
# ['10.145.0.157']
# ----------------------------------------------------
# Host : 10.145.0.157 (e5430loaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.194']
# ----------------------------------------------------
# Host : 10.145.0.194 (e5430testing-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.169']
# ----------------------------------------------------
# Host : 10.145.0.169 (e6530loaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.201']
# ----------------------------------------------------
# Host : 10.145.4.201 (e7450_2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.2.24']
# ----------------------------------------------------
# Host : 10.144.2.24 (esimensen-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.189']
# ----------------------------------------------------
# Host : 10.145.4.189 (gbirch-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.165']
# ----------------------------------------------------
# Host : 10.145.0.165 (gpioppi-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.2.131']
# ----------------------------------------------------
# Host : 10.144.2.131 (gsteir-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.104']
# ----------------------------------------------------
# Host : 10.145.0.104 (hwebster-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.157']
# ----------------------------------------------------
# Host : 10.145.4.157 (jborochaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.116']
# ----------------------------------------------------
# Host : 10.145.0.116 (jcross-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.191']
# ----------------------------------------------------
# Host : 10.145.4.191 (jdurff-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.2.20']
# ----------------------------------------------------
# Host : 10.144.2.20 (jenmazzoni-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.124']
# ----------------------------------------------------
# Host : 10.145.0.124 (jmazzarella-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.184']
# ----------------------------------------------------
# Host : 10.145.0.184 (jobrien-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.2.16']
# ----------------------------------------------------
# Host : 10.144.2.16 (jpeck-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.130']
# ----------------------------------------------------
# Host : 10.145.0.130 (jreynolds-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.191']
# ----------------------------------------------------
# Host : 10.145.0.191 (jsparling-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.162']
# ----------------------------------------------------
# Host : 10.145.4.162 (kamerman-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.2.151']
# ----------------------------------------------------
# Host : 10.144.2.151 (kblaine-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.49']
# ----------------------------------------------------
# Host : 10.145.4.49 (kbraddish-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.194']
# ----------------------------------------------------
# Host : 10.145.0.194 (kfrangiosa-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.245']
# ----------------------------------------------------
# Host : 10.145.0.245 (khammar-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.192']
# ----------------------------------------------------
# Host : 10.145.0.192 (kkamparath-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.167']
# ----------------------------------------------------
# Host : 10.145.4.167 (lbartow-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.197']
# ----------------------------------------------------
# Host : 10.145.0.197 (lbartow-wks)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.200']
# ----------------------------------------------------
# Host : 10.145.4.200 (lindsay-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.2.242']
# ----------------------------------------------------
# Host : 10.144.2.242 (lreed-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.156']
# ----------------------------------------------------
# Host : 10.145.0.156 (lreed2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.169']
# ----------------------------------------------------
# Host : 10.145.4.169 (lsaripalli-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.143']
# ----------------------------------------------------
# Host : 10.145.0.143 (lwapnitsky-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.4.195']
# ----------------------------------------------------
# Host : 10.145.4.195 (manthony-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.113']
# ----------------------------------------------------
# Host : 10.145.0.113 (marnold-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.166']
# ----------------------------------------------------
# Host : 10.145.0.166 (mdavis-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.171']
# ----------------------------------------------------
# Host : 10.145.0.171 (mgoldstein-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.155']
# ----------------------------------------------------
# Host : 10.145.4.155 (mhorsch-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.120']
# ----------------------------------------------------
# Host : 10.145.0.120 (mmainardi-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.166']
# ----------------------------------------------------
# Host : 10.145.4.166 (mrempfer-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.159']
# ----------------------------------------------------
# Host : 10.145.4.159 (msmith-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.187']
# ----------------------------------------------------
# Host : 10.145.0.187 (mstrassman-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.144.1.199']
# ----------------------------------------------------
# Host : 10.144.1.199 (nicole-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.141']
# ----------------------------------------------------
# Host : 10.145.0.141 (owen-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.160']
# ----------------------------------------------------
# Host : 10.145.0.160 (powers-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# []
# []
# ['10.145.4.189']
# ----------------------------------------------------
# Host : 10.145.4.189 (rbaretto-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# []
# ['10.144.1.242']
# ----------------------------------------------------
# Host : 10.144.1.242 (rgarrett-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.70']
# ----------------------------------------------------
# Host : 10.145.4.70 (rino-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.0.172']
# ----------------------------------------------------
# Host : 10.145.0.172 (shagarty-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.164']
# ----------------------------------------------------
# Host : 10.145.0.164 (snuzzo-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.126']
# ----------------------------------------------------
# Host : 10.145.4.126 (sreilly-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.0.102']
# ----------------------------------------------------
# Host : 10.144.0.102 (svats-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.145.4.161']
# ----------------------------------------------------
# Host : 10.145.4.161 (sweiland-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.181']
# ----------------------------------------------------
# Host : 10.145.0.181 (swray-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
# ['10.144.1.244']
# ----------------------------------------------------
# Host : 10.144.1.244 (tdunn2-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.109']
# ----------------------------------------------------
# Host : 10.145.0.109 (thall-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.4.160']
# ----------------------------------------------------
# Host : 10.145.4.160 (tharness-lt)
# Protocol : tcp
# 9102
# port : 9102	state : open
# ['10.145.0.202']
# ----------------------------------------------------
# Host : 10.145.0.202 (thoward-lt)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.216']
# ----------------------------------------------------
# Host : 10.145.0.216 (tlowell-wks)
# Protocol : tcp
# 9102
# port : 9102	state : closed
# ['10.145.0.146']
# ----------------------------------------------------
# Host : 10.145.0.146 (xpsloaner-lt)
# Protocol : tcp
# 9102
# port : 9102	state : filtered
